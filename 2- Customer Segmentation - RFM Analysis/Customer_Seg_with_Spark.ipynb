# %%
import findspark

# %%
findspark.init("/opt/manual/spark")

# %%
from pyspark.sql import SparkSession, functions as F
import pandas as pd
##from pyspark.sql.functions import col,datediff,lit,mean, min, max, sum, to_date,to_utc_timestamp, unix_timestamp
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder \
.appName("KMeans") \
.master("yarn") \
.config("spark.sql.shuffle.partitions","2") \
.getOrCreate()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
##! hdfs dfs -put /home/train/datasets/flo100k_data.csv /user/train/datasets/

# %%
df = spark.read.format("csv") \
.option("header", True) \
.option("inferSchema", True) \
.option("sep","|") \
.load("hdfs://localhost:9000/user/train/datasets/flo100k_data.csv")

# %% [markdown]
# ## Preprocessing Data

# %%
df.limit(5).toPandas()
# Out:
#    _c0                             master_id order_channel platform_type  \
# 0    0  b3ace094-a17f-11e9-a2fc-000d3a38a36f       Offline       Offline
# 1    1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f       Offline   OmniChannel
# 2    2  602897a6-cdac-11ea-b31f-000d3a38a36f       Offline       Offline
# 3    3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        Mobile        Online
# 4    4  80664354-adf0-11eb-8f64-000d3a299ebf       Desktop        Online
#
#   last_order_channel    first_order_date     last_order_date  \
# 0            Offline 2019-02-23 12:59:17 2019-02-23 12:59:17
# 1            Offline 2019-12-01 16:48:09 2019-12-01 16:48:09
# 2            Offline 2020-07-24 15:49:47 2020-07-24 15:49:47
# 3             Mobile 2018-12-31 07:22:07 2018-12-31 07:22:07
# 4            Desktop 2021-05-05 21:07:02 2021-05-05 22:39:36
#
#   last_order_date_online last_order_date_offline  order_num_total_ever_online  \
# 0                    NaT     2019-02-23 12:59:17                          NaN
# 1                    NaT     2019-12-01 16:48:09                          NaN
# 2                    NaT     2020-07-24 15:49:47                          NaN
# 3    2018-12-31 07:22:07                     NaT                          1.0
# 4    2021-05-05 22:39:36                     NaT                          2.0
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                           1.0                             212.98
# 1                           1.0                             199.98
# 2                           1.0                             140.49
# 3                           NaN                               0.00
# 4                           NaN                               0.00
#
#    customer_value_total_ever_online interested_in_categories_12  \
# 0                              0.00                        None
# 1                              0.00                        None
# 2                              0.00                     [ERKEK]
# 3                            174.99                        None
# 4                            283.95                          []
#
#   last_order_date_new
# 0          2019-02-23
# 1          2019-12-01
# 2          2020-07-24
# 3          2018-12-31
# 4          2021-05-05

# %%
df_count = df.count()
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- master_id: string (nullable = true)
#  |-- order_channel: string (nullable = true)
#  |-- platform_type: string (nullable = true)
#  |-- last_order_channel: string (nullable = true)
#  |-- first_order_date: timestamp (nullable = true)
#  |-- last_order_date: timestamp (nullable = true)
#  |-- last_order_date_online: timestamp (nullable = true)
#  |-- last_order_date_offline: timestamp (nullable = true)
#  |-- order_num_total_ever_online: double (nullable = true)
#  |-- order_num_total_ever_offline: double (nullable = true)
#  |-- customer_value_total_ever_offline: double (nullable = true)
#  |-- customer_value_total_ever_online: double (nullable = true)
#  |-- interested_in_categories_12: string (nullable = true)
#  |-- last_order_date_new: string (nullable = true)

# %%
len(df.columns)
# Out:
# 15

# %%
df.dtypes
# Out:
# [('_c0', 'int'),
#  ('master_id', 'string'),
#  ('order_channel', 'string'),
#  ('platform_type', 'string'),
#  ('last_order_channel', 'string'),
#  ('first_order_date', 'timestamp'),
#  ('last_order_date', 'timestamp'),
#  ('last_order_date_online', 'timestamp'),
#  ('last_order_date_offline', 'timestamp'),
#  ('order_num_total_ever_online', 'double'),
#  ('order_num_total_ever_offline', 'double'),
#  ('customer_value_total_ever_offline', 'double'),
#  ('customer_value_total_ever_online', 'double'),
#  ('interested_in_categories_12', 'string'),
#  ('last_order_date_new', 'string')]

# %% [markdown]
# ### Null Check

# %%
for col_name in df.dtypes:
    null_count = df.filter( (F.col(col_name[0]).isNull()) | (F.col(col_name[0]) == "")).count()
    
    if null_count > 0:
        print("{}  {} type null values: {} % {}".format(col_name[0], col_name[1], null_count, (null_count/df_count * 100)))
# Out:
# last_order_date_online  timestamp type null values: 70784 % 70.784
# last_order_date_offline  timestamp type null values: 21703 % 21.703
# order_num_total_ever_online  double type null values: 70784 % 70.784
# order_num_total_ever_offline  double type null values: 21703 % 21.703
# interested_in_categories_12  string type null values: 56590 % 56.589999999999996

# %%
df.select("master_id").distinct().count()
# Out:
# 100000

# %%
df = df.na.fill(value=0,subset=["order_num_total_ever_online"])
df = df.na.fill(value=0,subset=["order_num_total_ever_offline"])

# %% [markdown]
# ### Grouping Attributes by Types, Handling Categorical Attributes

# %%
categoric_cols = []

numeric_cols = []

discarted_cols = ['_c0', 'master_id', 'first_order_date', 'last_order_date','last_order_date_online','last_order_date_offline','last_order_date_new','interested_in_categories_12' ]

label_col = []

# %%
for col_name in df.dtypes:
    if (col_name[0] not in discarted_cols+label_col):
        if col_name[1] == 'string':
            categoric_cols.append(col_name[0])
        else: numeric_cols.append(col_name[0])

# %%
print(categoric_cols)
print(len(categoric_cols))
# Out:
# ['order_channel', 'platform_type', 'last_order_channel']
# 3

# %%
print(numeric_cols)
print(len(numeric_cols))
# Out:
# ['order_num_total_ever_online', 'order_num_total_ever_offline', 'customer_value_total_ever_offline', 'customer_value_total_ever_online']
# 4

# %%
print(discarted_cols)
print(len(discarted_cols))
# Out:
# ['_c0', 'master_id', 'first_order_date', 'last_order_date', 'last_order_date_online', 'last_order_date_offline', 'last_order_date_new', 'interested_in_categories_12']
# 8

# %%
print(label_col)
print(len(label_col))
# Out:
# []
# 0

# %% [markdown]
# ### Examine Categoric Columns

# %%
for col_name in categoric_cols:
    df.select(col_name).groupBy(col_name).count().show()
# Out:
# +-------------+-----+
# |order_channel|count|
# +-------------+-----+
# |      Offline|70784|
# |      Ios App| 3964|
# |       Mobile| 8512|
# |      Desktop| 4751|
# |  Android App|11989|
# +-------------+-----+
#
# +-------------+-----+
# |platform_type|count|
# +-------------+-----+
# |      Offline|65991|
# |  OmniChannel|12569|
# |       Online|21440|
# +-------------+-----+
#
# +------------------+-----+
# |last_order_channel|count|
# +------------------+-----+
# |           Offline|73766|
# |           Ios App| 3347|
# |            Mobile| 7630|
# |           Desktop| 4604|
# |       Android App|10653|
# +------------------+-----+

# %% [markdown]
# ### Verifying Cols

# %%
if len(df.columns) == (len(categoric_cols)+len(numeric_cols)+len(discarted_cols+label_col)):
    print("Columns are OK")
else: print("Check columns AGAIN!")
# Out:
# Columns are OK

# %% [markdown]
# ### Data Analysis

# %%
df=df.withColumn("order_number_total", col("order_num_total_ever_offline")+col("order_num_total_ever_online"))

# %%
df=df.withColumn("customer_value_total", col("customer_value_total_ever_online")+col("customer_value_total_ever_offline"))
df.limit(40).toPandas()
# Out:
#     _c0                             master_id order_channel platform_type  \
# 0     0  b3ace094-a17f-11e9-a2fc-000d3a38a36f       Offline       Offline
# 1     1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f       Offline   OmniChannel
# 2     2  602897a6-cdac-11ea-b31f-000d3a38a36f       Offline       Offline
# 3     3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        Mobile        Online
# 4     4  80664354-adf0-11eb-8f64-000d3a299ebf       Desktop        Online
# 5     5  47511f36-aeb4-11e9-a2fc-000d3a38a36f   Android App        Online
# 6     6  77f7c318-3407-11eb-9a15-000d3a38a36f   Android App        Online
# 7     7  399d6dd2-ecf1-11ea-9369-000d3a38a36f       Offline       Offline
# 8     8  b3d4a6f2-a368-11e9-a2fc-000d3a38a36f       Offline       Offline
# 9     9  42fdccd4-f1d1-11ea-bde9-000d3a38a36f       Desktop        Online
# 10   10  071b497c-a5d2-11e9-a2fc-000d3a38a36f        Mobile        Online
# 11   11  47d99768-30ea-11ea-b884-000d3a38a36f       Offline       Offline
# 12   12  f879c85e-5322-11ea-acd3-000d3a38a36f       Offline       Offline
# 13   13  cfb38c70-b1e7-11e9-89fa-000d3a38a36f        Mobile   OmniChannel
# 14   14  96cae10c-bbd1-11ea-9a91-000d3a38a36f       Offline       Offline
# 15   15  20df63fa-5411-11ea-b1db-000d3a38a36f       Offline   OmniChannel
# 16   16  757fc81a-7378-11ea-92d0-000d3a38a36f       Offline       Offline
# 17   17  c9fcbc34-d739-11ea-aceb-000d3a38a36f       Offline       Offline
# 18   18  9f44ad8c-21fc-11ea-ba6f-000d3a38a36f       Offline       Offline
# 19   19  3fcf9680-9765-11ea-a9c8-000d3a38a36f   Android App        Online
# 20   20  40416b44-a2ff-11e9-a2fc-000d3a38a36f       Offline       Offline
# 21   21  bb0f9ef4-5b05-11ea-b898-000d3a38a36f       Offline       Offline
# 22   22  64c54112-af0a-11ea-b736-000d3a38a36f       Offline       Offline
# 23   23  ba94ea90-9fb4-11e9-a2fc-000d3a38a36f       Ios App        Online
# 24   24  19ddb2d6-a710-11e9-a2fc-000d3a38a36f       Offline   OmniChannel
# 25   25  16a9326e-2629-11ea-8e1c-000d3a38a36f       Offline       Offline
# 26   26  56788052-733f-11eb-a9a7-000d3a38a36f       Offline       Offline
# 27   27  f7c00a62-d691-11e9-93bc-000d3a38a36f       Offline       Offline
# 28   28  3ad5da12-a26b-11e9-a2fc-000d3a38a36f       Offline       Offline
# 29   29  0beee1e6-5baf-11ea-b67a-000d3a38a36f   Android App   OmniChannel
# 30   30  cbb599ca-8d41-11ea-8f41-000d3a38a36f       Desktop        Online
# 31   31  7e02591e-602a-11ea-8dd8-000d3a38a36f   Android App        Online
# 32   32  253a88ee-5b05-11ea-a29d-000d3a38a36f       Offline       Offline
# 33   33  d46060ca-2eda-11ea-8467-000d3a38a36f       Offline       Offline
# 34   34  3476dda8-d328-11ea-9838-000d3a38a36f       Offline       Offline
# 35   35  d35c13f2-5b50-11ea-ab87-000d3a38a36f       Offline       Offline
# 36   36  380ff71c-62dd-11ea-a6dc-000d3a38a36f       Offline       Offline
# 37   37  8f701e1e-b1f9-11e9-89fa-000d3a38a36f       Offline       Offline
# 38   38  fcd0b928-17d8-11eb-8d74-000d3a38a36f       Ios App        Online
# 39   39  f89a81ae-46e1-11ea-b6c0-000d3a38a36f       Ios App   OmniChannel
#
#    last_order_channel    first_order_date     last_order_date  \
# 0             Offline 2019-02-23 12:59:17 2019-02-23 12:59:17
# 1             Offline 2019-12-01 16:48:09 2019-12-01 16:48:09
# 2             Offline 2020-07-24 15:49:47 2020-07-24 15:49:47
# 3              Mobile 2018-12-31 07:22:07 2018-12-31 07:22:07
# 4             Desktop 2021-05-05 21:07:02 2021-05-05 22:39:36
# 5         Android App 2018-11-11 11:26:51 2018-11-11 11:26:51
# 6         Android App 2020-12-01 20:38:41 2020-12-01 20:38:41
# 7             Offline 2020-09-02 10:51:09 2020-09-02 10:51:09
# 8             Offline 2019-03-29 16:53:07 2020-09-24 17:37:25
# 9             Desktop 2020-10-18 22:59:55 2020-10-18 22:59:55
# 10             Mobile 2018-09-25 12:22:12 2021-03-22 21:56:33
# 11            Offline 2019-08-04 21:51:10 2019-08-04 21:53:09
# 12            Offline 2020-01-30 15:47:21 2020-01-30 15:47:21
# 13            Offline 2019-07-21 19:41:05 2020-01-11 13:22:22
# 14            Offline 2019-09-07 17:28:51 2020-07-01 19:37:22
# 15            Offline 2020-01-17 21:05:33 2020-01-17 21:05:33
# 16            Offline 2019-12-11 11:32:01 2021-03-26 12:23:12
# 17            Offline 2020-08-05 19:31:34 2020-08-05 19:31:34
# 18            Offline 2019-04-05 12:57:42 2019-04-05 12:57:42
# 19        Android App 2020-05-12 14:47:13 2020-05-12 14:47:13
# 20            Offline 2019-03-22 16:01:10 2019-03-22 16:01:10
# 21            Offline 2020-02-16 13:26:48 2020-02-16 13:26:48
# 22            Offline 2020-06-15 16:14:52 2020-06-15 16:49:15
# 23            Ios App 2019-03-25 08:11:33 2020-02-25 23:27:54
# 24            Offline 2019-08-10 18:09:13 2021-01-21 16:53:41
# 25            Offline 2019-10-05 16:42:19 2019-10-05 16:42:19
# 26            Offline 2021-02-18 19:19:10 2021-02-18 19:19:10
# 27            Offline 2019-08-28 13:42:14 2019-08-28 13:42:14
# 28            Offline 2019-03-12 12:17:59 2019-03-12 12:17:59
# 29        Android App 2019-04-30 11:00:07 2020-06-12 21:27:05
# 30            Desktop 2020-05-03 16:30:03 2020-05-03 16:30:03
# 31        Android App 2020-01-26 23:27:05 2021-05-01 21:21:44
# 32            Offline 2019-12-31 16:23:30 2019-12-31 16:23:30
# 33            Offline 2019-11-16 15:13:08 2019-11-16 15:13:08
# 34            Offline 2020-07-31 15:18:45 2020-07-31 15:18:45
# 35            Offline 2020-02-20 17:25:37 2020-06-18 20:33:58
# 36            Offline 2020-03-07 17:28:13 2020-03-07 17:28:13
# 37            Offline 2019-07-23 15:43:53 2019-07-23 15:43:53
# 38            Ios App 2020-10-27 01:24:36 2020-10-27 01:24:36
# 39            Offline 2019-12-03 11:47:47 2019-12-04 18:00:20
#
#    last_order_date_online last_order_date_offline  \
# 0                     NaT     2019-02-23 12:59:17
# 1                     NaT     2019-12-01 16:48:09
# 2                     NaT     2020-07-24 15:49:47
# 3     2018-12-31 07:22:07                     NaT
# 4     2021-05-05 22:39:36                     NaT
# 5     2018-11-11 11:26:51                     NaT
# 6     2020-12-01 20:38:41                     NaT
# 7                     NaT     2020-09-02 10:51:09
# 8                     NaT     2020-09-24 17:37:25
# 9     2020-10-18 22:59:55                     NaT
# 10    2021-03-22 21:56:33                     NaT
# 11                    NaT     2019-08-04 21:53:09
# 12                    NaT     2020-01-30 15:47:21
# 13    2019-11-27 21:30:02     2020-01-11 13:22:22
# 14                    NaT     2020-07-01 19:37:22
# 15                    NaT     2020-01-17 21:05:33
# 16                    NaT     2021-03-26 12:23:12
# 17                    NaT     2020-08-05 19:31:34
# 18                    NaT     2019-04-05 12:57:42
# 19    2020-05-12 14:47:13                     NaT
# 20                    NaT     2019-03-22 16:01:10
# 21                    NaT     2020-02-16 13:26:48
# 22                    NaT     2020-06-15 16:49:15
# 23    2020-02-25 23:27:54                     NaT
# 24                    NaT     2021-01-21 16:53:41
# 25                    NaT     2019-10-05 16:42:19
# 26                    NaT     2021-02-18 19:19:10
# 27                    NaT     2019-08-28 13:42:14
# 28                    NaT     2019-03-12 12:17:59
# 29    2020-06-12 21:27:05     2020-01-14 15:19:58
# 30    2020-05-03 16:30:03                     NaT
# 31    2021-05-01 21:21:44                     NaT
# 32                    NaT     2019-12-31 16:23:30
# 33                    NaT     2019-11-16 15:13:08
# 34                    NaT     2020-07-31 15:18:45
# 35                    NaT     2020-06-18 20:33:58
# 36                    NaT     2020-03-07 17:28:13
# 37                    NaT     2019-07-23 15:43:53
# 38    2020-10-27 01:24:36                     NaT
# 39    2019-12-03 14:47:51     2019-12-04 18:00:20
#
#     order_num_total_ever_online  order_num_total_ever_offline  \
# 0                           0.0                           1.0
# 1                           0.0                           1.0
# 2                           0.0                           1.0
# 3                           1.0                           0.0
# 4                           2.0                           0.0
# 5                           1.0                           0.0
# 6                           1.0                           0.0
# 7                           0.0                           1.0
# 8                           0.0                           3.0
# 9                           1.0                           0.0
# 10                          7.0                           0.0
# 11                          0.0                           2.0
# 12                          0.0                           1.0
# 13                          2.0                           1.0
# 14                          0.0                           2.0
# 15                          0.0                           1.0
# 16                          0.0                           2.0
# 17                          0.0                           1.0
# 18                          0.0                           1.0
# 19                          1.0                           0.0
# 20                          0.0                           1.0
# 21                          0.0                           1.0
# 22                          0.0                           2.0
# 23                          3.0                           0.0
# 24                          0.0                           4.0
# 25                          0.0                           1.0
# 26                          0.0                           1.0
# 27                          0.0                           1.0
# 28                          0.0                           1.0
# 29                          1.0                           2.0
# 30                          1.0                           0.0
# 31                          2.0                           0.0
# 32                          0.0                           1.0
# 33                          0.0                           1.0
# 34                          0.0                           1.0
# 35                          0.0                           3.0
# 36                          0.0                           1.0
# 37                          0.0                           1.0
# 38                          1.0                           0.0
# 39                          1.0                           3.0
#
#     customer_value_total_ever_offline  customer_value_total_ever_online  \
# 0                              212.98                              0.00
# 1                              199.98                              0.00
# 2                              140.49                              0.00
# 3                                0.00                            174.99
# 4                                0.00                            283.95
# 5                                0.00                            139.98
# 6                                0.00                            269.90
# 7                               95.73                              0.00
# 8                              207.94                              0.00
# 9                                0.00                            134.95
# 10                               0.00                            399.94
# 11                             304.89                              0.00
# 12                             100.49                              0.00
# 13                             109.99                             98.97
# 14                             359.96                              0.00
# 15                              39.99                              0.00
# 16                             630.94                              0.00
# 17                             289.99                              0.00
# 18                             189.99                              0.00
# 19                               0.00                             89.99
# 20                             259.90                              0.00
# 21                             100.73                              0.00
# 22                             110.95                              0.00
# 23                               0.00                            577.30
# 24                             678.42                              0.00
# 25                             139.99                              0.00
# 26                             115.86                              0.00
# 27                              29.99                              0.00
# 28                             149.99                              0.00
# 29                             252.96                            125.99
# 30                               0.00                            531.30
# 31                               0.00                            454.10
# 32                             149.99                              0.00
# 33                               9.99                              0.00
# 34                             399.99                              0.00
# 35                             566.87                              0.00
# 36                             120.49                              0.00
# 37                              99.99                              0.00
# 38                               0.00                            234.98
# 39                             179.97                            269.99
#
#    interested_in_categories_12 last_order_date_new  order_number_total  \
# 0                         None          2019-02-23                 1.0
# 1                         None          2019-12-01                 1.0
# 2                      [ERKEK]          2020-07-24                 1.0
# 3                         None          2018-12-31                 1.0
# 4                           []          2021-05-05                 2.0
# 5                         None          2018-11-11                 1.0
# 6                  [AKTIFSPOR]          2020-12-01                 1.0
# 7           [KADIN, AKTIFSPOR]          2020-09-02                 1.0
# 8               [ERKEK, KADIN]          2020-09-24                 3.0
# 9                           []          2020-10-18                 1.0
# 10                     [KADIN]          2021-03-22                 7.0
# 11                        None          2019-08-04                 2.0
# 12                        None          2020-01-30                 1.0
# 13                        None          2020-01-11                 3.0
# 14         [AKTIFCOCUK, KADIN]          2020-07-01                 2.0
# 15                        None          2020-01-17                 1.0
# 16                          []          2021-03-26                 2.0
# 17                 [AKTIFSPOR]          2020-08-05                 1.0
# 18                        None          2019-04-05                 1.0
# 19                        None          2020-05-12                 1.0
# 20                        None          2019-03-22                 1.0
# 21                        None          2020-02-16                 1.0
# 22   [ERKEK, KADIN, AKTIFSPOR]          2020-06-15                 2.0
# 23                        None          2020-02-25                 3.0
# 24          [COCUK, AKTIFSPOR]          2021-01-21                 4.0
# 25                        None          2019-10-05                 1.0
# 26          [KADIN, AKTIFSPOR]          2021-02-18                 1.0
# 27                        None          2019-08-28                 1.0
# 28                        None          2019-03-12                 1.0
# 29                     [ERKEK]          2020-06-12                 3.0
# 30                        None          2020-05-03                 1.0
# 31                          []          2021-05-01                 2.0
# 32                        None          2019-12-31                 1.0
# 33                        None          2019-11-16                 1.0
# 34                 [AKTIFSPOR]          2020-07-31                 1.0
# 35                 [AKTIFSPOR]          2020-06-18                 3.0
# 36                        None          2020-03-07                 1.0
# 37                        None          2019-07-23                 1.0
# 38                 [AKTIFSPOR]          2020-10-27                 1.0
# 39                        None          2019-12-04                 4.0
#
#     customer_value_total
# 0                 212.98
# 1                 199.98
# 2                 140.49
# 3                 174.99
# 4                 283.95
# 5                 139.98
# 6                 269.90
# 7                  95.73
# 8                 207.94
# 9                 134.95
# 10                399.94
# 11                304.89
# 12                100.49
# 13                208.96
# 14                359.96
# 15                 39.99
# 16                630.94
# 17                289.99
# 18                189.99
# 19                 89.99
# 20                259.90
# 21                100.73
# 22                110.95
# 23                577.30
# 24                678.42
# 25                139.99
# 26                115.86
# 27                 29.99
# 28                149.99
# 29                378.95
# 30                531.30
# 31                454.10
# 32                149.99
# 33                  9.99
# 34                399.99
# 35                566.87
# 36                120.49
# 37                 99.99
# 38                234.98
# 39                449.96

# %%
df.select('order_num_total_ever_offline').filter("order_num_total_ever_offline is NULL").show()
# Out:
# +----------------------------+
# |order_num_total_ever_offline|
# +----------------------------+
# +----------------------------+

# %%
df.select('order_num_total_ever_online').filter("order_num_total_ever_online is NULL").show()
# Out:
# +---------------------------+
# |order_num_total_ever_online|
# +---------------------------+
# +---------------------------+

# %%
df.groupBy("order_channel").count().orderBy(F.desc("count")).show()
df.groupBy("order_channel").avg("order_number_total").show()
df.groupBy("order_channel").avg("customer_value_total").show()
# Out:
# +-------------+-----+
# |order_channel|count|
# +-------------+-----+
# |      Offline|70784|
# |  Android App|11989|
# |       Mobile| 8512|
# |      Desktop| 4751|
# |      Ios App| 3964|
# +-------------+-----+
#
# +-------------+-----------------------+
# |order_channel|avg(order_number_total)|
# +-------------+-----------------------+
# |      Offline|     1.6003475361663653|
# |      Ios App|      3.377648839556004|
# |       Mobile|      2.798637218045113|
# |      Desktop|      2.538623447695222|
# |  Android App|       3.50971724080407|
# +-------------+-----------------------+
#
# +-------------+-------------------------+
# |order_channel|avg(customer_value_total)|
# +-------------+-------------------------+
# |      Offline|        218.1639484912975|
# |      Ios App|        568.4640312815283|
# |      Desktop|       376.91355504103785|
# |  Android App|        532.8462840937639|
# |       Mobile|        391.7418761748011|
# +-------------+-------------------------+

# %%
df.groupBy("platform_type").count().orderBy(F.desc("count")).show()
df.groupBy("platform_type").avg("order_number_total").show()
df.groupBy("platform_type").avg("customer_value_total").show()
# Out:
# +-------------+-----+
# |platform_type|count|
# +-------------+-----+
# |      Offline|65991|
# |       Online|21440|
# |  OmniChannel|12569|
# +-------------+-----+
#
# +-------------+-----------------------+
# |platform_type|avg(order_number_total)|
# +-------------+-----------------------+
# |  OmniChannel|     3.4947092051873656|
# |      Offline|     1.5837917291751906|
# |       Online|     2.6207089552238805|
# +-------------+-----------------------+
#
# +-------------+-------------------------+
# |platform_type|avg(customer_value_total)|
# +-------------+-------------------------+
# |      Offline|       215.73030686012984|
# |  OmniChannel|        500.7937512928769|
# |       Online|       404.78965764929046|
# +-------------+-------------------------+

# %% [markdown]
# ### RFM

# %%
rfm_df = df.select("master_id","last_order_date_new","order_number_total","customer_value_total")

# %%
rfm_df = rfm_df.withColumn("Recency", expr("datediff('2021-06-02', last_order_date_new)"))
rfm_df = rfm_df.withColumnRenamed("order_number_total","Frequency")
rfm_df = rfm_df.withColumnRenamed("customer_value_total","Monetary")
rfm_df = rfm_df.drop(col("last_order_date_new"))

# %%
rfm_df.limit(5).toPandas()
# Out:
#                               master_id  Frequency  Monetary  Recency
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f        1.0    212.98      830
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f        1.0    199.98      549
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f        1.0    140.49      313
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        1.0    174.99      884
# 4  80664354-adf0-11eb-8f64-000d3a299ebf        2.0    283.95       28

# %% [markdown]
# ### Feature Engineering

# %%
rfm_df = (
    rfm_df.withColumn("Monetary", 
        F.when(F.col("Monetary") <= 0, 1)
         .otherwise(F.col("Monetary")))
)

# %%
features = rfm_df.columns[1:]

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(
    inputCols=features, 
    outputCol="unscaled_features")
assembled_data = assembler.transform(rfm_df)
assembled_data = assembled_data.select(
    'master_id', 'unscaled_features')

# %%
from pyspark.ml.feature import StandardScaler
scaler = StandardScaler(inputCol='unscaled_features',
outputCol='features')
data_scale = scaler.fit(assembled_data)
scaled_data = data_scale.transform(assembled_data)

# %% [markdown]
# ### Pipeline

# %%
from pyspark.ml import Pipeline
pipeline_obj = Pipeline().setStages([assembler, scaler])
pipeline_model = pipeline_obj.fit(rfm_df)
pipeline_df = pipeline_model.transform(rfm_df)
pipeline_df.limit(5).toPandas()
# Out:
#                               master_id  Frequency  Monetary  Recency  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f        1.0    212.98      830
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f        1.0    199.98      549
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f        1.0    140.49      313
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        1.0    174.99      884
# 4  80664354-adf0-11eb-8f64-000d3a299ebf        2.0    283.95       28
#
#       unscaled_features                                           features
# 0  [1.0, 212.98, 830.0]  [0.3277012075046896, 0.4598811451772491, 3.251...
# 1  [1.0, 199.98, 549.0]  [0.3277012075046896, 0.43181064612896175, 2.15...
# 2  [1.0, 140.49, 313.0]  [0.3277012075046896, 0.3033557239456838, 1.226...
# 3  [1.0, 174.99, 884.0]  [0.3277012075046896, 0.3778505098815233, 3.463...
# 4   [2.0, 283.95, 28.0]  [0.6554024150093792, 0.6131244772893224, 0.109...

# %% [markdown]
# ### K-Means Model

# %%
from pyspark.ml.clustering import KMeans
def compute_kmeans_model(rfm_df, k):
    kmeansObject = KMeans() \
        .setK(k)\
        .setFeaturesCol("features")
        
    return kmeansObject.fit(rfm_df)

# %% [markdown]
# ### Evaluator

# %%
from pyspark.ml.evaluation import ClusteringEvaluator
evaluator = ClusteringEvaluator()

# %%
for k in range(2,11):
    kmeans_model = compute_kmeans_model(pipeline_df, k)
    
    transformed_df = kmeans_model.transform(pipeline_df)
    
    score = evaluator.evaluate(transformed_df)
    
    print("k: {}, score: {}" .format(k, score))
# Out:
# k: 2, score: 0.7571631251678737
# k: 3, score: 0.6559715046000123
# k: 4, score: 0.6806248838694781
# k: 5, score: 0.6662493724566684
# k: 6, score: 0.532569710909801
# k: 7, score: 0.5348584726699458
# k: 8, score: 0.5532034595835308
# k: 9, score: 0.5497715659455591
# k: 10, score: 0.5445172495425756

# %%
kmeans_model = compute_kmeans_model(pipeline_df, 2)

# %%
transformed_df = kmeans_model.transform(pipeline_df)

# %%
transformed_df.limit(5).toPandas()
# Out:
#                               master_id  Frequency  Monetary  Recency  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f        1.0    212.98      830
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f        1.0    199.98      549
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f        1.0    140.49      313
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        1.0    174.99      884
# 4  80664354-adf0-11eb-8f64-000d3a299ebf        2.0    283.95       28
#
#       unscaled_features                                           features  \
# 0  [1.0, 212.98, 830.0]  [0.3277012075046896, 0.4598811451772491, 3.251...
# 1  [1.0, 199.98, 549.0]  [0.3277012075046896, 0.43181064612896175, 2.15...
# 2  [1.0, 140.49, 313.0]  [0.3277012075046896, 0.3033557239456838, 1.226...
# 3  [1.0, 174.99, 884.0]  [0.3277012075046896, 0.3778505098815233, 3.463...
# 4   [2.0, 283.95, 28.0]  [0.6554024150093792, 0.6131244772893224, 0.109...
#
#    prediction
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ## Statistical summary

# %%
transformed_df.groupBy('prediction')\
       .agg({'Recency':'mean',
             'Frequency': 'mean',
             'Monetary': 'mean'} )\
        .sort(F.col('prediction')).show()
# Out:
# +----------+------------------+------------------+-----------------+
# |prediction|      avg(Recency)|     avg(Monetary)|   avg(Frequency)|
# +----------+------------------+------------------+-----------------+
# |         0| 443.9831130854056|202.49118453961572|1.520648243225144|
# |         1|161.57891195693963| 1063.729280084586|6.572952710495963|
# +----------+------------------+------------------+-----------------+
